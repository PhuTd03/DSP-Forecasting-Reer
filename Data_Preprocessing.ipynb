# %%
import numpy as np
# import matplotlib.pyplot as plt
import pandas as pd
# import seaborn as sns

# %% [markdown]
# # Foreign exchange rate
# Exchange Rate prives of different currencies to USD
#
# dataset = concate(forex.csv , craw_exchange_data)

# %%
data_file_old = "raw_data/forex.csv"
data_old = pd.read_csv(data_file_old, index_col='Date')
data_old.tail()
# Out:
#                AUD     EUR     NZD     GBP     BRL     CAD     CNY     DKK  \
# Date
# 2020-08-17  0.7211  1.1869  0.6547  1.3105  5.4734  1.3202  6.9318  6.2727
# 2020-08-18  0.7235  1.1928  0.6588  1.3228  5.4845  1.3181  6.9215  6.2406
# 2020-08-19  0.7234  1.1898  0.6607  1.3191  5.5045  1.3173  6.9192   6.258
# 2020-08-20  0.7178  1.1862  0.6519   1.319   5.637  1.3177  6.9143  6.2783
# 2020-08-21  0.7156  1.1775  0.6533  1.3098  5.5949  1.3201  6.9179  6.3235
#
#                HKD    INR  ...     NOK      ZAR     SGD      KRW     LKR  \
# Date                       ...
# 2020-08-17  7.7503  74.74  ...  8.8633    17.46  1.3679  1184.17  183.13
# 2020-08-18  7.7501  74.62  ...  8.8387  17.3525  1.3647  1184.74  184.23
# 2020-08-19    7.75  74.85  ...  8.8504    17.18   1.366  1181.06   186.1
# 2020-08-20    7.75  75.01  ...  8.9437   17.275  1.3676  1187.66  184.35
# 2020-08-21  7.7502  74.92  ...  9.0457  17.1275  1.3723  1191.84   184.5
#
# ...

# %%
data_file_new = "raw_data/craw_exchange_rates.csv"
data_new = pd.read_csv(data_file_new, index_col='Date')
data_new.head()
# Out:
#             Argentine Peso  Australian Dollar  Bahraini Dinar  Botswana Pula  \
# Date
# 2020-08-22       73.579256           1.396602           0.376      11.637555
# 2020-08-23       73.579557           1.395563           0.376      11.637555
# 2020-08-24       73.710014           1.393959           0.376      11.643542
# 2020-08-25       73.804240           1.392982           0.376      11.621302
# 2020-08-26       73.857449           1.384584           0.376      11.621117
#
#             Brazilian Real  British Pound  Bruneian Dollar  Bulgarian Lev  \
# Date
# 2020-08-22        5.618639       0.763911         1.371719       1.657960
# 2020-08-23        5.620804       0.763985         1.371610       1.657235
# 2020-08-24        5.601739       0.764626         1.369650       1.657013
# 2020-08-25        5.606940       0.761295         1.369387       1.654960
# 2020-08-26        5.600594       0.758394         1.366561       1.655690
#
# ...

# %%
for col in data_new.columns:
    if col not in ['Date', 'Australian Dollar', 'Euro', 'New Zealand Dollar', 'British Pound', 'Brazilian Real', 'Canadian Dollar', 'Chinese Yuan Renminbi', 'Danish Krone', 'Hong Kong Dollar', 'Indian Rupee', 'Japanese Yen', 'Malaysian Ringgit', 'Mexican Peso', 'Norwegian Krone', 'South African Rand', 'Singapore Dollar', 'South Korean Won', 'Sri Lankan Rupee', 'Swedish Krona', 'Swiss Franc', 'Taiwan New Dollar', 'Thai Baht', 'Venezuelan Bolivar']:
        data_new = data_new.drop(columns=col)

# %%
# rename all columns in data to match data in the data_old
data_new = data_new.rename(columns={'Australian Dollar': 'AUD', 'Euro': 'EUR', 'New Zealand Dollar': 'NZD', 'British Pound': 'GBP', 'Brazilian Real': 'BRL', 'Canadian Dollar': 'CAD', 'Chinese Yuan Renminbi': 'CNY', 'Danish Krone': 'DKK', 'Hong Kong Dollar': 'HKD', 'Indian Rupee': 'INR', 'Japanese Yen': 'JPY', 'Malaysian Ringgit': 'MYR', 'Mexican Peso': 'MXN', 'Norwegian Krone': 'NOK', 'South African Rand': 'ZAR', 'Singapore Dollar': 'SGD', 'South Korean Won': 'KRW', 'Sri Lankan Rupee': 'LKR', 'Swedish Krona': 'SEK', 'Swiss Franc': 'CHF', 'Taiwan New Dollar': 'TWD', 'Thai Baht': 'THB', 'Venezuelan Bolivar': 'VEB'})

# rearrange columns in data to match data_old
data_new = data_new[['AUD', 'EUR', 'NZD', 'GBP', 'BRL', 'CAD', 'CNY', 'DKK', 'HKD', 'INR', 'JPY', 'MYR', 'MXN', 'NOK', 'ZAR', 'SGD', 'KRW', 'LKR', 'SEK', 'CHF', 'TWD', 'THB', 'VEB']]

# drop rows with NaN values
data_new = data_new.drop(data_new[data_new.values == 'ND'].index)

# %%
data_new.info()
data_new.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1394 entries, 2020-08-22 to 2024-06-15
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AUD     1394 non-null   float64
#  1   EUR     1394 non-null   float64
#  2   NZD     1394 non-null   float64
#  3   GBP     1394 non-null   float64
#  4   BRL     1394 non-null   float64
#  5   CAD     1394 non-null   float64
#  6   CNY     1394 non-null   float64
#  7   DKK     1394 non-null   float64
#  8   HKD     1394 non-null   float64
#  9   INR     1394 non-null   float64
#  10  JPY     1394 non-null   float64
#  11  MYR     1394 non-null   float64
#  12  MXN     1394 non-null   float64
#  13  NOK     1394 non-null   float64
#  14  ZAR     1394 non-null   float64
#  15  SGD     1394 non-null   float64
#  16  KRW     1394 non-null   float64
#  17  LKR     1394 non-null   float64
#  18  SEK     1394 non-null   float64
#  19  CHF     1394 non-null   float64
# ...

# %%
# convert all values to numeric
# data_new = data.apply(pd.to_numeric)

# %%
data_new.head()
# Out:
#                  AUD       EUR       NZD       GBP       BRL       CAD  \
# Date
# 2020-08-22  1.396602  0.847702  1.528191  0.763911  5.618639  1.318061
# 2020-08-23  1.395563  0.847331  1.529008  0.763985  5.620804  1.317663
# 2020-08-24  1.393959  0.847217  1.529953  0.764626  5.601739  1.321918
# 2020-08-25  1.392982  0.846168  1.531507  0.761295  5.606940  1.319180
# 2020-08-26  1.384584  0.846541  1.515130  0.758394  5.600594  1.314637
#
#                  CNY       DKK       HKD        INR  ...       NOK        ZAR  \
# Date                                                 ...
# 2020-08-22  6.918983  6.311640  7.750382  74.945117  ...  9.012533  17.153688
# 2020-08-23  6.918471  6.311767  7.750209  74.945209  ...  9.010828  17.151668
# 2020-08-24  6.919940  6.306667  7.750069  74.178602  ...  8.995832  16.936985
# 2020-08-25  6.913134  6.297897  7.750692  74.226103  ...  8.978172  16.867176
# 2020-08-26  6.886889  6.301694  7.750277  74.243657  ...  8.921152  16.977582
#
# ...

# %%
# merge data and data_old
forex = pd.concat([data_old, data_new])
forex = forex.drop(forex[forex.values == 'ND'].index)

# convert all values to numeric
forex = forex.apply(pd.to_numeric)
forex.head(20)
# Out:
#                AUD     EUR     NZD     GBP     BRL     CAD     CNY     DKK  \
# Date
# 2000-01-03  0.6591  1.0155  0.5254  1.6270  1.8050  1.4465  8.2798  7.3290
# 2000-01-04  0.6562  1.0309  0.5198  1.6370  1.8405  1.4518  8.2799  7.2180
# 2000-01-05  0.6550  1.0335  0.5171  1.6415  1.8560  1.4518  8.2798  7.2080
# 2000-01-06  0.6540  1.0324  0.5145  1.6475  1.8400  1.4571  8.2797  7.2125
# 2000-01-07  0.6548  1.0294  0.5160  1.6384  1.8310  1.4505  8.2794  7.2285
# 2000-01-10  0.6561  1.0252  0.5168  1.6374  1.8190  1.4568  8.2794  7.2540
# 2000-01-11  0.6575  1.0322  0.5164  1.6480  1.8225  1.4570  8.2795  7.2140
# 2000-01-12  0.6578  1.0281  0.5185  1.6465  1.8350  1.4550  8.2796  7.2360
# 2000-01-13  0.6687  1.0270  0.5240  1.6482  1.8140  1.4495  8.2798  7.2520
# 2000-01-14  0.6665  1.0128  0.5212  1.6353  1.8050  1.4497  8.2797  7.3470
# 2000-01-18  0.6640  1.0121  0.5170  1.6380  1.7942  1.4502  8.2793  7.3560
# ...

# %%
forex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6566 entries, 2000-01-03 to 2024-06-15
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AUD     6566 non-null   float64
#  1   EUR     6566 non-null   float64
#  2   NZD     6566 non-null   float64
#  3   GBP     6566 non-null   float64
#  4   BRL     6566 non-null   float64
#  5   CAD     6566 non-null   float64
#  6   CNY     6566 non-null   float64
#  7   DKK     6566 non-null   float64
#  8   HKD     6566 non-null   float64
#  9   INR     6566 non-null   float64
#  10  JPY     6566 non-null   float64
#  11  MYR     6566 non-null   float64
#  12  MXN     6566 non-null   float64
#  13  NOK     6566 non-null   float64
#  14  ZAR     6566 non-null   float64
#  15  SGD     6566 non-null   float64
#  16  KRW     6566 non-null   float64
#  17  LKR     6566 non-null   float64
#  18  SEK     6566 non-null   float64
#  19  CHF     6566 non-null   float64
# ...

# %%
# save the data to a new csv file
forex.to_csv('dataset.csv')

# %% [markdown]
# # GDP
# Using squeeze=True to acquire the data as a Series instead of Dataframe.

# %%
file_GBP = "raw_data/gdp_GBP.csv"
gdpGBP = pd.read_csv(file_GBP, index_col="DATE", parse_dates=True)
gdpGBP = gdpGBP.squeeze(True)

#chage the name
gdpGBP.name = "GDP in GBP"

gdpGBP
# Out:
# DATE
# 2000-01-01    100.84230
# 2000-02-01    100.90500
# 2000-03-01    100.93520
# 2000-04-01    100.93770
# 2000-05-01    100.91940
#                 ...
# 2023-04-01     99.88166
# 2023-05-01     99.85315
# 2023-06-01     99.81881
# 2023-07-01     99.78423
# 2023-08-01     99.75476
# Name: GDP in GBP, Length: 284, dtype: float64

# %%
file_USD = "raw_data/gdp_USA.csv"
gdpUSD = pd.read_csv(file_USD, index_col="DATE", parse_dates=True)
gdpUSD = gdpUSD.squeeze(True)

#chage the name
gdpUSD.name = "GDP in USD"

gdpUSD
# Out:
# DATE
# 2000-01-01    101.5195
# 2000-02-01    101.5818
# 2000-03-01    101.6581
# 2000-04-01    101.7313
# 2000-05-01    101.7747
#                 ...
# 2023-07-01    100.0677
# 2023-08-01    100.1888
# 2023-09-01    100.3023
# 2023-10-01    100.4033
# 2023-11-01    100.4912
# Name: GDP in USD, Length: 287, dtype: float64

# %%
# concate the two Series and merge with the forex data
gdp = pd.concat([gdpGBP, gdpUSD], axis=1, keys=['gdpGBP', 'gdpUSD'])
gdp.dtypes
# Out:
# gdpGBP    float64
# gdpUSD    float64
# dtype: object

# %%
# Convert the index of gdp to datetime
gdp.index = pd.to_datetime(gdp.index)

# Convert the index of forex to the same type as gdp
forex.index = forex.index.astype(gdp.index.dtype)

# %%
# merging the two dataframes forex and gdp on the index
data = pd.merge(forex, gdp, left_index=True, right_index=True, how='outer')
data
# Out:
#                  AUD       EUR       NZD       GBP       BRL       CAD  \
# 2000-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2000-01-03  0.659100  1.015500  0.525400  1.627000  1.805000  1.446500
# 2000-01-04  0.656200  1.030900  0.519800  1.637000  1.840500  1.451800
# 2000-01-05  0.655000  1.033500  0.517100  1.641500  1.856000  1.451800
# 2000-01-06  0.654000  1.032400  0.514500  1.647500  1.840000  1.457100
# ...              ...       ...       ...       ...       ...       ...
# 2024-06-11  1.515841  0.931735  1.631062  0.786051  5.353400  1.376758
# 2024-06-12  1.492555  0.922254  1.608355  0.778792  5.391727  1.369258
# 2024-06-13  1.505802  0.929766  1.620082  0.783488  5.378350  1.374745
# 2024-06-14  1.511768  0.934700  1.628520  0.788411  5.356692  1.373957
# 2024-06-15  1.512134  0.933782  1.627663  0.788277  5.377250  1.374093
#
#                  CNY       DKK       HKD        INR  ...       SGD  \
# ...

# %% [markdown]
# # Current Account

# %%
file_name = "raw_data/CA.csv"
data_ca = pd.read_csv(file_name)
data_ca.drop(columns={"SUBJECT", "Subject", "Country", "MEASURE", "Measure", "FREQUENCY", "Frequency", "Time", "Unit Code", "Unit", "PowerCode Code", "PowerCode", "Reference Period Code", "Reference Period", "Flag Codes", "Flags"}, inplace=True)

data_ca
# Out:
#     LOCATION     TIME     Value
# 0        USA  2000-Q1 -3.790054
# 1        USA  2000-Q2 -3.762476
# 2        USA  2000-Q3 -4.050100
# 3        USA  2000-Q4 -4.073653
# 4        USA  2001-Q1 -4.092976
# ..       ...      ...       ...
# 185      GBR  2022-Q3 -1.880823
# 186      GBR  2022-Q4  0.635486
# 187      GBR  2023-Q1 -2.379062
# 188      GBR  2023-Q2 -3.546464
# 189      GBR  2023-Q3 -2.506553
#
# [190 rows x 3 columns]

# %%
# df of the data for USA
data_ca_USA = data_ca[data_ca["LOCATION"] == "USA"]
data_ca_USA.drop(columns={"LOCATION"}, inplace=True)
data_ca_USA.set_index("TIME", inplace=True)
data_ca_USA
# Out:
# /var/folders/qk/ct1q8p117253m_wtrxf4d__00000gn/T/ipykernel_21691/155229223.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ca_USA.drop(columns={"LOCATION"}, inplace=True)
#             Value
# TIME
# 2000-Q1 -3.790054
# 2000-Q2 -3.762476
# 2000-Q3 -4.050100
# 2000-Q4 -4.073653
# 2001-Q1 -4.092976
# ...           ...
# 2022-Q3 -3.427737
# 2022-Q4 -3.274018
# 2023-Q1 -3.199451
# 2023-Q2 -3.204448
# 2023-Q3 -2.901892
#
# [95 rows x 1 columns]

# %%
# df of the data for GBR
data_ca_GBP = data_ca[data_ca["LOCATION"] == "GBR"]
data_ca_GBP.drop(columns={"LOCATION"}, inplace=True)
data_ca_GBP.set_index("TIME", inplace=True)
data_ca_GBP
# Out:
# /var/folders/qk/ct1q8p117253m_wtrxf4d__00000gn/T/ipykernel_21691/1149466889.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_ca_GBP.drop(columns={"LOCATION"}, inplace=True)
#             Value
# TIME
# 2000-Q1 -1.596646
# 2000-Q2 -1.576924
# 2000-Q3 -2.005314
# 2000-Q4 -2.137916
# 2001-Q1 -1.013332
# ...           ...
# 2022-Q3 -1.880823
# 2022-Q4  0.635486
# 2023-Q1 -2.379062
# 2023-Q2 -3.546464
# 2023-Q3 -2.506553
#
# [95 rows x 1 columns]

# %%
# merge the USA and GBR data, each quarter
data_ca = pd.merge(data_ca_GBP, data_ca_USA, left_index=True, right_index=True, how='outer', suffixes=('_GBP', '_USA'))

# rename the columns TIME to Date
data_ca.index.names = ['Date']

# to csv
data_ca.to_csv('raw_data/data_ca.csv')

# %%
data_ca.index
# Out:
# Index(['2000-Q1', '2000-Q2', '2000-Q3', '2000-Q4', '2001-Q1', '2001-Q2',
#        '2001-Q3', '2001-Q4', '2002-Q1', '2002-Q2', '2002-Q3', '2002-Q4',
#        '2003-Q1', '2003-Q2', '2003-Q3', '2003-Q4', '2004-Q1', '2004-Q2',
#        '2004-Q3', '2004-Q4', '2005-Q1', '2005-Q2', '2005-Q3', '2005-Q4',
#        '2006-Q1', '2006-Q2', '2006-Q3', '2006-Q4', '2007-Q1', '2007-Q2',
#        '2007-Q3', '2007-Q4', '2008-Q1', '2008-Q2', '2008-Q3', '2008-Q4',
#        '2009-Q1', '2009-Q2', '2009-Q3', '2009-Q4', '2010-Q1', '2010-Q2',
#        '2010-Q3', '2010-Q4', '2011-Q1', '2011-Q2', '2011-Q3', '2011-Q4',
#        '2012-Q1', '2012-Q2', '2012-Q3', '2012-Q4', '2013-Q1', '2013-Q2',
#        '2013-Q3', '2013-Q4', '2014-Q1', '2014-Q2', '2014-Q3', '2014-Q4',
#        '2015-Q1', '2015-Q2', '2015-Q3', '2015-Q4', '2016-Q1', '2016-Q2',
#        '2016-Q3', '2016-Q4', '2017-Q1', '2017-Q2', '2017-Q3', '2017-Q4',
#        '2018-Q1', '2018-Q2', '2018-Q3', '2018-Q4', '2019-Q1', '2019-Q2',
# ...

# %%
# Convert the index of data to datetime
data_ca.index = pd.to_datetime(data_ca.index.str.replace(r'(Q\d)-(\d+)', r'\2-\1'))
data_ca
# Out:
# /var/folders/qk/ct1q8p117253m_wtrxf4d__00000gn/T/ipykernel_21691/1983504331.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data_ca.index = pd.to_datetime(data_ca.index.str.replace(r'(Q\d)-(\d+)', r'\2-\1'))
#             Value_GBP  Value_USA
# Date
# 2000-01-01  -1.596646  -3.790054
# 2000-04-01  -1.576924  -3.762476
# 2000-07-01  -2.005314  -4.050100
# 2000-10-01  -2.137916  -4.073653
# 2001-01-01  -1.013332  -4.092976
# ...               ...        ...
# 2022-07-01  -1.880823  -3.427737
# 2022-10-01   0.635486  -3.274018
# 2023-01-01  -2.379062  -3.199451
# 2023-04-01  -3.546464  -3.204448
# 2023-07-01  -2.506553  -2.901892
#
# [95 rows x 2 columns]

# %%
# Indexes became datetime object
data_ca.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-04-01', '2000-07-01', '2000-10-01',
#                '2001-01-01', '2001-04-01', '2001-07-01', '2001-10-01',
#                '2002-01-01', '2002-04-01', '2002-07-01', '2002-10-01',
#                '2003-01-01', '2003-04-01', '2003-07-01', '2003-10-01',
#                '2004-01-01', '2004-04-01', '2004-07-01', '2004-10-01',
#                '2005-01-01', '2005-04-01', '2005-07-01', '2005-10-01',
#                '2006-01-01', '2006-04-01', '2006-07-01', '2006-10-01',
#                '2007-01-01', '2007-04-01', '2007-07-01', '2007-10-01',
#                '2008-01-01', '2008-04-01', '2008-07-01', '2008-10-01',
#                '2009-01-01', '2009-04-01', '2009-07-01', '2009-10-01',
#                '2010-01-01', '2010-04-01', '2010-07-01', '2010-10-01',
#                '2011-01-01', '2011-04-01', '2011-07-01', '2011-10-01',
#                '2012-01-01', '2012-04-01', '2012-07-01', '2012-10-01',
# ...

# %%
# merge dataset
data = pd.merge(data, data_ca, left_index=True, right_index=True, how='outer')
data
# Out:
#                  AUD       EUR       NZD       GBP       BRL       CAD  \
# 2000-01-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2000-01-03  0.659100  1.015500  0.525400  1.627000  1.805000  1.446500
# 2000-01-04  0.656200  1.030900  0.519800  1.637000  1.840500  1.451800
# 2000-01-05  0.655000  1.033500  0.517100  1.641500  1.856000  1.451800
# 2000-01-06  0.654000  1.032400  0.514500  1.647500  1.840000  1.457100
# ...              ...       ...       ...       ...       ...       ...
# 2024-06-11  1.515841  0.931735  1.631062  0.786051  5.353400  1.376758
# 2024-06-12  1.492555  0.922254  1.608355  0.778792  5.391727  1.369258
# 2024-06-13  1.505802  0.929766  1.620082  0.783488  5.378350  1.374745
# 2024-06-14  1.511768  0.934700  1.628520  0.788411  5.356692  1.373957
# 2024-06-15  1.512134  0.933782  1.627663  0.788277  5.377250  1.374093
#
#                  CNY       DKK       HKD        INR  ...         LKR  \
# ...

# %% [markdown]
# # Libor rate

# %%
file_name = "raw_data/libor_data_USD.csv"
liborUSD = pd.read_csv(file_name, index_col="Date", parse_dates=True)
liborUSD = liborUSD.squeeze(True)
# drop all columns except Avg
liborUSD = liborUSD["Average"]
liborUSD
# Out:
# Date
# 2000-01-01    5.64752
# 2000-02-01    5.84138
# 2000-03-01    5.96000
# 2000-04-01    6.10579
# 2000-05-01    6.43857
#                ...
# 2024-08-01          -
# 2024-09-01          -
# 2024-10-01          -
# 2024-11-01          -
# 2024-12-01          -
# Name: Average, Length: 300, dtype: object

# %%
file_name = "raw_data/libor_data_GBP.csv"
liborGBP = pd.read_csv(file_name, index_col="Date", parse_dates=True)
liborGBP = liborGBP.squeeze(True)
# drop all columns except Avg
liborGBP = liborGBP["Average"]
liborGBP
# Out:
# Date
# 2000-01-01    5.50508
# 2000-02-01    5.97114
# 2000-03-01    5.88913
# 2000-04-01    6.02586
# 2000-05-01    5.99906
#                ...
# 2024-08-01          -
# 2024-09-01          -
# 2024-10-01          -
# 2024-11-01          -
# 2024-12-01          -
# Name: Average, Length: 300, dtype: object

# %%
# concate the two Series and and make them dataframe
libor = pd.concat([liborUSD, liborGBP], axis=1, keys=['liborUSD', 'liborGBP'])
libor
# Out:
#            liborUSD liborGBP
# Date
# 2000-01-01  5.64752  5.50508
# 2000-02-01  5.84138  5.97114
# 2000-03-01  5.96000  5.88913
# 2000-04-01  6.10579  6.02586
# 2000-05-01  6.43857  5.99906
# ...             ...      ...
# 2024-08-01        -        -
# 2024-09-01        -        -
# 2024-10-01        -        -
# 2024-11-01        -        -
# 2024-12-01        -        -
#
# [300 rows x 2 columns]

# %%
# Some of the values are in "-"
libor[libor["liborUSD"] == "-"]

# # Convert Series values to numeric
# libor = libor.apply(pd.to_numeric, errors='coerce')
# libor.info()
# Out:
#            liborUSD liborGBP
# Date
# 2023-07-01        -        -
# 2023-08-01        -        -
# 2023-09-01        -        -
# 2023-10-01        -        -
# 2023-11-01        -        -
# 2023-12-01        -        -
# 2024-07-01        -        -
# 2024-08-01        -        -
# 2024-09-01        -        -
# 2024-10-01        -        -
# 2024-11-01        -        -
# 2024-12-01        -        -

# %%
dataset = pd.merge(data, libor, left_index=True, right_index=True, how='outer')
dataset[:5]
# Out:
#                AUD     EUR     NZD     GBP     BRL     CAD     CNY     DKK  \
# 2000-01-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2000-01-03  0.6591  1.0155  0.5254  1.6270  1.8050  1.4465  8.2798  7.3290
# 2000-01-04  0.6562  1.0309  0.5198  1.6370  1.8405  1.4518  8.2799  7.2180
# 2000-01-05  0.6550  1.0335  0.5171  1.6415  1.8560  1.4518  8.2798  7.2080
# 2000-01-06  0.6540  1.0324  0.5145  1.6475  1.8400  1.4571  8.2797  7.2125
#
#                HKD    INR  ...     CHF    TWD    THB     VEB    gdpGBP  \
# 2000-01-01     NaN    NaN  ...     NaN    NaN    NaN     NaN  100.8423
# 2000-01-03  7.7765  43.55  ...  1.5808  31.38  36.97  0.6498       NaN
# 2000-01-04  7.7775  43.55  ...  1.5565  30.60  37.13  0.6503       NaN
# 2000-01-05  7.7780  43.55  ...  1.5526  30.80  37.10  0.6515       NaN
# 2000-01-06  7.7785  43.55  ...  1.5540  31.75  37.62  0.6503       NaN
#
#               gdpUSD  Value_GBP  Value_USA  liborUSD  liborGBP
# ...

# %%
# interpolation needs continuous datetime
# or numerical objects for index values
dataset.reset_index(level=0, inplace=True)
dataset
# Out:
#           index     AUD     EUR     NZD     GBP     BRL     CAD     CNY  \
# 0    2000-01-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1    2000-01-03  0.6591  1.0155  0.5254  1.6270  1.8050  1.4465  8.2798
# 2    2000-01-04  0.6562  1.0309  0.5198  1.6370  1.8405  1.4518  8.2799
# 3    2000-01-05  0.6550  1.0335  0.5171  1.6415  1.8560  1.4518  8.2798
# 4    2000-01-06  0.6540  1.0324  0.5145  1.6475  1.8400  1.4571  8.2797
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 6658 2024-08-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6659 2024-09-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6660 2024-10-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6661 2024-11-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6662 2024-12-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          DKK     HKD  ...     CHF    TWD    THB     VEB    gdpGBP    gdpUSD  \
# ...

# %%
# deleta all rows with NaN values after 2024-06-15
dataset = dataset.dropna(subset=['AUD'])
dataset
# Out:
#           index       AUD       EUR       NZD       GBP       BRL       CAD  \
# 1    2000-01-03  0.659100  1.015500  0.525400  1.627000  1.805000  1.446500
# 2    2000-01-04  0.656200  1.030900  0.519800  1.637000  1.840500  1.451800
# 3    2000-01-05  0.655000  1.033500  0.517100  1.641500  1.856000  1.451800
# 4    2000-01-06  0.654000  1.032400  0.514500  1.647500  1.840000  1.457100
# 5    2000-01-07  0.654800  1.029400  0.516000  1.638400  1.831000  1.450500
# ...         ...       ...       ...       ...       ...       ...       ...
# 6652 2024-06-11  1.515841  0.931735  1.631062  0.786051  5.353400  1.376758
# 6653 2024-06-12  1.492555  0.922254  1.608355  0.778792  5.391727  1.369258
# 6654 2024-06-13  1.505802  0.929766  1.620082  0.783488  5.378350  1.374745
# 6655 2024-06-14  1.511768  0.934700  1.628520  0.788411  5.356692  1.373957
# 6656 2024-06-15  1.512134  0.933782  1.627663  0.788277  5.377250  1.374093
#
# ...

# %%
# fill the missing values by interpolation
dataset.iloc[:, -6:] = dataset.iloc[:, -6:].interpolate()
dataset
# Out:
# /var/folders/qk/ct1q8p117253m_wtrxf4d__00000gn/T/ipykernel_21691/731217491.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   dataset.iloc[:, -6:] = dataset.iloc[:, -6:].interpolate()
#           index       AUD       EUR       NZD       GBP       BRL       CAD  \
# 1    2000-01-03  0.659100  1.015500  0.525400  1.627000  1.805000  1.446500
# 2    2000-01-04  0.656200  1.030900  0.519800  1.637000  1.840500  1.451800
# 3    2000-01-05  0.655000  1.033500  0.517100  1.641500  1.856000  1.451800
# 4    2000-01-06  0.654000  1.032400  0.514500  1.647500  1.840000  1.457100
# 5    2000-01-07  0.654800  1.029400  0.516000  1.638400  1.831000  1.450500
# ...         ...       ...       ...       ...       ...       ...       ...
# 6652 2024-06-11  1.515841  0.931735  1.631062  0.786051  5.353400  1.376758
# ...

# %%
# drop rows where there is no data for GBP (or any forex)
dataset = dataset[dataset.GBP.notna()]
dataset
# Out:
#           index       AUD       EUR       NZD       GBP       BRL       CAD  \
# 1    2000-01-03  0.659100  1.015500  0.525400  1.627000  1.805000  1.446500
# 2    2000-01-04  0.656200  1.030900  0.519800  1.637000  1.840500  1.451800
# 3    2000-01-05  0.655000  1.033500  0.517100  1.641500  1.856000  1.451800
# 4    2000-01-06  0.654000  1.032400  0.514500  1.647500  1.840000  1.457100
# 5    2000-01-07  0.654800  1.029400  0.516000  1.638400  1.831000  1.450500
# ...         ...       ...       ...       ...       ...       ...       ...
# 6652 2024-06-11  1.515841  0.931735  1.631062  0.786051  5.353400  1.376758
# 6653 2024-06-12  1.492555  0.922254  1.608355  0.778792  5.391727  1.369258
# 6654 2024-06-13  1.505802  0.929766  1.620082  0.783488  5.378350  1.374745
# 6655 2024-06-14  1.511768  0.934700  1.628520  0.788411  5.356692  1.373957
# 6656 2024-06-15  1.512134  0.933782  1.627663  0.788277  5.377250  1.374093
#
# ...

# %%
# there is not enough data for libor series at the beginning
# I drop the beginning rows of the whole dataframe
dataset = dataset[dataset.liborGBP.notna()]
dataset
# Out:
#           index       AUD       EUR       NZD       GBP       BRL       CAD  \
# 21   2000-02-01  0.631500  0.973100  0.490400  1.615000  1.795000  1.446800
# 41   2000-03-01  0.606700  0.970000  0.485300  1.584900  1.769000  1.447000
# 85   2000-05-01  0.580000  0.912000  0.483500  1.555800  1.807000  1.478300
# 107  2000-06-01  0.572100  0.930700  0.456100  1.491500  1.821000  1.491000
# 150  2000-08-01  0.580500  0.922800  0.454600  1.499200  1.786000  1.489200
# ...         ...       ...       ...       ...       ...       ...       ...
# 6521 2024-02-01  1.522934  0.920376  1.630278  0.785825  4.919647  1.338190
# 6550 2024-03-01  1.531798  0.923196  1.638305  0.790470  4.948222  1.355491
# 6581 2024-04-01  1.542390  0.931698  1.682959  0.797231  5.066569  1.358095
# 6611 2024-05-01  1.539960  0.936355  1.694729  0.800790  5.195355  1.376123
# 6642 2024-06-01  1.502668  0.921543  1.627486  0.784984  5.246579  1.363570
#
# ...

# %%
# count the number of NaN values in the value_GDP
dataset.isna().sum()
# Out:
# index         0
# AUD           0
# EUR           0
# NZD           0
# GBP           0
# BRL           0
# CAD           0
# CNY           0
# DKK           0
# HKD           0
# INR           0
# JPY           0
# MYR           0
# MXN           0
# NOK           0
# ZAR           0
# SGD           0
# KRW           0
# LKR           0
# SEK           0
# CHF           0
# TWD           0
# THB           0
# VEB           0
# gdpGBP        0
# gdpUSD        0
# Value_GBP    13
# Value_USA    13
# liborUSD      0
# liborGBP      0
# dtype: int64

# %%
# examine the final data
rename_dict = {
    'index': 'Date',
    'Value_GBP': 'GBR_Value',
    'Value_USA': 'USA_Value',
    'liborUSD': 'liborUSD',
    'liborGBP': 'liborGBP'
}

# Renaming the columns
dataset.rename(columns=rename_dict, inplace=True)
dataset.info()
dataset.describe()
# Out:
# /var/folders/qk/ct1q8p117253m_wtrxf4d__00000gn/T/ipykernel_21691/3451975486.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.rename(columns=rename_dict, inplace=True)
# <class 'pandas.core.frame.DataFrame'>
# Index: 203 entries, 21 to 6642
# Data columns (total 30 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       203 non-null    datetime64[ns]
#  1   AUD        203 non-null    float64
#  2   EUR        203 non-null    float64
#  3   NZD        203 non-null    float64
#  4   GBP        203 non-null    float64
#  5   BRL        203 non-null    float64
#  6   CAD        203 non-null    float64
#  7   CNY        203 non-null    float64
#  8   DKK        203 non-null    float64
#  9   HKD        203 non-null    float64
# ...

# %%
# write dataset to dataset.csv
dataset.to_csv('dataset.csv', index=False)

# %%
x = pd.read_csv('dataset.csv')
x
# Out:
#            Date       AUD       EUR       NZD       GBP       BRL       CAD  \
# 0    2000-02-01  0.631500  0.973100  0.490400  1.615000  1.795000  1.446800
# 1    2000-03-01  0.606700  0.970000  0.485300  1.584900  1.769000  1.447000
# 2    2000-05-01  0.580000  0.912000  0.483500  1.555800  1.807000  1.478300
# 3    2000-06-01  0.572100  0.930700  0.456100  1.491500  1.821000  1.491000
# 4    2000-08-01  0.580500  0.922800  0.454600  1.499200  1.786000  1.489200
# ..          ...       ...       ...       ...       ...       ...       ...
# 198  2024-02-01  1.522934  0.920376  1.630278  0.785825  4.919647  1.338190
# 199  2024-03-01  1.531798  0.923196  1.638305  0.790470  4.948222  1.355491
# 200  2024-04-01  1.542390  0.931698  1.682959  0.797231  5.066569  1.358095
# 201  2024-05-01  1.539960  0.936355  1.694729  0.800790  5.195355  1.376123
# 202  2024-06-01  1.502668  0.921543  1.627486  0.784984  5.246579  1.363570
#
# ...
